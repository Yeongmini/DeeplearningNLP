# %% [markdown]
# 8-3 게이트 순환 유닛(Gated Recurrent Unit, GRU)\
# GRU는 LSTM의 장기 의존성 문제에 대한 해결책을 유지하면서, 은닉 상태를 업데이트하는 계산을 줄였다.\
# 즉, GRU는 성능은 LSTM과 유사하면서 복잡했던 LSTM의 구조를 간단화 시켰다.

# %% [markdown]
# 1. GRU(Gated Recurrent Unit)\
# LSTM에서는 출력,입력,삭제 게이트라는 3개의 게이트가 존재하였다.\
# 반면 GRU에서는 업데이트 게이트와 리셋 게이트 두 가지 게이트만 존재한다.

# %% [markdown]
# ![image.png](attachment:image.png)\
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 둘 중 더 낫다라고 판명하기는 어려우며, 기존에 LSTM을 사용하면서 최적의 하이퍼파라미터를 찾아낸 상황이라면 \
# 굳이 GRU로 바꿔서 사용할 필요는 없다.

# %% [markdown]
# 경험적으로 데이터 양이 적을 때는 매개 변수 양이 적은 GRU가 조금 더 낫고, 데이터 양이 더 많으면 LSTM이 더 낫다고도 한다.

# %% [markdown]
# 2. 케라스에서의 GRU(Gated Rucurrent Unit)

# %%
model.add(GRU(hidden_size, input_shape = (timesteps, input_dim)))
